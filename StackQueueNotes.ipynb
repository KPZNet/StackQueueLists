# %%
from QueueRunner import QueueRunner
from Queues import QueueLinkedList
from Queues import QueueList
import pandas as pd

import time

from IPython.display import display


#%Full to Empty%

sr = QueueRunner ()

queue_times_df = pd.DataFrame ()

queue_times_df["RunA_List"] = [sr.RunQueueList(100, 1000, QueueList())]
queue_times_df["RunA_LinkedList"] = [sr.RunQueueList ( 100, 1000, QueueLinkedList () )]

queue_times_df["RunB_List"] = [sr.RunQueueList(1, 100000, QueueList())]
queue_times_df["RunB_LinkedList"] = [sr.RunQueueList ( 1, 100000, QueueLinkedList () )]

queue_times_df["RunC_List"] = [sr.RunQueueList(100000, 1, QueueList())]
queue_times_df["RunC_LinkedList"] = [sr.RunQueueList ( 100000, 1, QueueLinkedList () )]


sr.plot_queue_comparisons_bg(queue_times_df)
display(queue_times_df)


#%Mid Queue%

sr = QueueRunner ()

queue_times_df = pd.DataFrame ()


queue_times_df["RunD_List"] = [sr.RunQueueList2(1000, 500, 1, QueueList())]
queue_times_df["RunD_LinkedList"] = [sr.RunQueueList2 ( 1000, 500, 1, QueueLinkedList () )]

queue_times_df["RunE_List"] = [sr.RunQueueList2(1, 500, 1000, QueueList())]
queue_times_df["RunE_LinkedList"] = [sr.RunQueueList2 ( 1, 500, 1000, QueueLinkedList () )]

sr.plot_queue_comparisons_bg(queue_times_df)
display(queue_times_df)
# Out:
#     RunA_List  RunA_LinkedList    RunB_List  RunB_LinkedList   RunC_List  \
# 0  154.513402       199.990463  1831.751166       224.371497  204.596978
#
#    RunC_LinkedList
# 0       191.130227
#    RunD_List  RunD_LinkedList  RunE_List  RunE_LinkedList
# 0   2.555771         2.406518   1.843335         1.896984
