# %%
from QueueRunner import QueueRunner
from StackRunner import StackRunner
from Queues import QueueLinkedList
from Queues import QueueList
from Stacks import StackList
from Stacks import StackLinkedList

import pandas as pd
from IPython.display import display

# %%
sr = QueueRunner ()

queue_times_df = pd.DataFrame ()

queue_times_df["100-1000_L"] = [sr.RunQueueList(100, 1000, QueueList())]
queue_times_df["100-1000_LL"] = [sr.RunQueueList ( 100, 1000, QueueLinkedList () )]

queue_times_df["1-100000_L"] = [sr.RunQueueList(1, 100000, QueueList())]
queue_times_df["1-100000_LL"] = [sr.RunQueueList ( 1, 100000, QueueLinkedList () )]

queue_times_df["100000-1_L"] = [sr.RunQueueList(100000, 1, QueueList())]
queue_times_df["100000-1_LL"] = [sr.RunQueueList ( 100000, 1, QueueLinkedList () )]


sr.plot_queue_comparisons_bg(queue_times_df)
display(queue_times_df)
# Out:
#    100-1000_L  100-1000_LL  1-100000_L  1-100000_LL  100000-1_L  100000-1_LL
# 0     77.5338      99.0763   1019.6764     143.3093    117.1361     105.4208

# %%
sr = QueueRunner ()

queue_times_df = pd.DataFrame ()

queue_times_df["100-500-1000_L"] = [sr.RunQueueList2(100, 500, 1000, QueueList())]
queue_times_df["100-500-1000_LL"] = [sr.RunQueueList2 ( 100, 500, 1000, QueueLinkedList () )]

queue_times_df["1000-500-1_L"] = [sr.RunQueueList2(100000, 500, 1, QueueList())]
queue_times_df["1000-500-1_LL"] = [sr.RunQueueList2 ( 100000, 500, 1, QueueLinkedList () )]

queue_times_df["1-500-1000_L"] = [sr.RunQueueList2(1, 500, 100000, QueueList())]
queue_times_df["1-500-1000_LL"] = [sr.RunQueueList2 ( 1, 500, 100000, QueueLinkedList () )]

sr.plot_queue_comparisons_bg(queue_times_df)
display(queue_times_df)
# Out:
#    100-500-1000_L  100-500-1000_LL  1000-500-1_L  1000-500-1_LL  1-500-1000_L  \
# 0          83.187         109.7783      112.2007       117.5289      1035.523
#
#    1-500-1000_LL
# 0       163.3771

# %%
sr = StackRunner()
stack_times_df = pd.DataFrame ()

stack_times_df["100-1000_L"] = [sr.RunStackList(100, 1000, StackList())]
stack_times_df["100-1000_LL"] = [sr.RunStackList ( 100, 1000, StackLinkedList () )]

stack_times_df["1-100000_L"] = [sr.RunStackList(1, 100000, StackList())]
stack_times_df["1-100000_LL"] = [sr.RunStackList ( 1, 100000, StackLinkedList () )]

stack_times_df["100000-1_L"] = [sr.RunStackList(100000, 1, StackList())]
stack_times_df["100000-1_LL"] = [sr.RunStackList ( 100000, 1, StackLinkedList () )]

sr.plot_stack_comparisons_bg(stack_times_df)

# %%
sr = StackRunner ()

stack_times_df = pd.DataFrame ()

stack_times_df["1000-500-1_L"] = [sr.RunStackList2(100000, 500, 1, StackList())]
stack_times_df["1000-500-1_LL"] = [sr.RunStackList2 ( 100000, 500, 1, StackLinkedList () )]

stack_times_df["1-500-1000_L"] = [sr.RunStackList2(1, 500, 100000, StackList())]
stack_times_df["1-500-1000_LL"] = [sr.RunStackList2 ( 1, 500, 100000, StackLinkedList () )]

sr.plot_stack_comparisons_bg(queue_times_df)
display(queue_times_df)
# Out:
#    1000-500-1_L  1000-500-1_LL  1-500-1000_L  1-500-1000_LL
# 0      116.9281        112.251      1004.284        150.789
